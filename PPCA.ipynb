# %%
import pandas as pd

# %%
df = pd.read_csv("D:\\workfuck\VVVV\dataset1.csv" ,encoding = 'unicode_escape')

# %%
df['Date_statistics'].describe()
# Out:
# count        1048575
# unique           389
# top       14/12/2020
# freq           12428
# Name: Date_statistics, dtype: object

# %%
df['Date_statistics_type'].describe()
# Out:
# count     1048574
# unique          5
# top           DOO
# freq       923851
# Name: Date_statistics_type, dtype: object

# %%
df['Agegroup'].describe()
# Out:
# count     1048575
# unique         14
# top         20-29
# freq       184170
# Name: Agegroup, dtype: object

# %%
df['Sex'].describe()
# Out:
# count     1048575
# unique          7
# top        Female
# freq       561550
# Name: Sex, dtype: object

# %%
df['Province'].describe()
# Out:
# count          1048575
# unique              19
# top       Zuid-Holland
# freq            249876
# Name: Province, dtype: object

# %%
df['Hospital_admission'].describe()
# Out:
# count     1048575
# unique          7
# top            No
# freq       926080
# Name: Hospital_admission, dtype: object

# %%
df['Week_of_death'].describe()
# Out:
# count     15830.000000
# mean     202047.862160
# std          33.769981
# min      202010.000000
# 25%      202016.000000
# 50%      202044.000000
# 75%      202053.000000
# max      202122.000000
# Name: Week_of_death, dtype: float64

# %%
df['Municipal_health_service'].describe()
# Out:
# count                    1048575
# unique                        33
# top       GGD Rotterdam-Rijnmond
# freq                       95639
# Name: Municipal_health_service, dtype: object

# %%
df['Date_statistics'].describe()
# Out:
# count        1048575
# unique           389
# top       14/12/2020
# freq           12428
# Name: Date_statistics, dtype: object

# %%
duplicate = df[df.duplicated()]
 
print("Date_statistics :")
duplicate
# Out:
# Date_statistics :
#         Date_statistics Date_statistics_type Agegroup     Sex       Province  \
# 82           23/02/2020                  DOO    70-79    Male  Noord-Brabant
# 94           24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 95           24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 109          24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 122          25/02/2020                  DOO    60-69    Male  Noord-Brabant
# ...                 ...                  ...      ...     ...            ...
# 1048570      16/02/2021                  DOO    40-49  Female        Utrecht
# 1048571      16/02/2021                  DOO   Oct-19  Female        Utrecht
# 1048572      16/02/2021                  DOO    20-29  Female        Utrecht
# 1048573      16/02/2021                  DOO    20-29  Female   Zuid-Holland
# 1048574      16/02/2021                  DOO    20-29  Female  Noord-Holland
#
# ...

# %%
duplicate = df[df.duplicated()]
 
print("Agegroup :")
duplicate
# Out:
# Agegroup :
#         Date_statistics Date_statistics_type Agegroup     Sex       Province  \
# 82           23/02/2020                  DOO    70-79    Male  Noord-Brabant
# 94           24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 95           24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 109          24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 122          25/02/2020                  DOO    60-69    Male  Noord-Brabant
# ...                 ...                  ...      ...     ...            ...
# 1048570      16/02/2021                  DOO    40-49  Female        Utrecht
# 1048571      16/02/2021                  DOO   Oct-19  Female        Utrecht
# 1048572      16/02/2021                  DOO    20-29  Female        Utrecht
# 1048573      16/02/2021                  DOO    20-29  Female   Zuid-Holland
# 1048574      16/02/2021                  DOO    20-29  Female  Noord-Holland
#
# ...

# %%
duplicate = df[df.duplicated()]
 
print("Sex :")
duplicate
# Out:
# Sex :
#         Date_statistics Date_statistics_type Agegroup     Sex       Province  \
# 82           23/02/2020                  DOO    70-79    Male  Noord-Brabant
# 94           24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 95           24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 109          24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 122          25/02/2020                  DOO    60-69    Male  Noord-Brabant
# ...                 ...                  ...      ...     ...            ...
# 1048570      16/02/2021                  DOO    40-49  Female        Utrecht
# 1048571      16/02/2021                  DOO   Oct-19  Female        Utrecht
# 1048572      16/02/2021                  DOO    20-29  Female        Utrecht
# 1048573      16/02/2021                  DOO    20-29  Female   Zuid-Holland
# 1048574      16/02/2021                  DOO    20-29  Female  Noord-Holland
#
# ...

# %%
duplicate = df[df.duplicated()]
 
print("Province :")
duplicate
# Out:
# Province :
#         Date_statistics Date_statistics_type Agegroup     Sex       Province  \
# 82           23/02/2020                  DOO    70-79    Male  Noord-Brabant
# 94           24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 95           24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 109          24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 122          25/02/2020                  DOO    60-69    Male  Noord-Brabant
# ...                 ...                  ...      ...     ...            ...
# 1048570      16/02/2021                  DOO    40-49  Female        Utrecht
# 1048571      16/02/2021                  DOO   Oct-19  Female        Utrecht
# 1048572      16/02/2021                  DOO    20-29  Female        Utrecht
# 1048573      16/02/2021                  DOO    20-29  Female   Zuid-Holland
# 1048574      16/02/2021                  DOO    20-29  Female  Noord-Holland
#
# ...

# %%
duplicate = df[df.duplicated()]
 
print("Hospital_admission :")
duplicate
# Out:
# Hospital_admission :
#         Date_statistics Date_statistics_type Agegroup     Sex       Province  \
# 82           23/02/2020                  DOO    70-79    Male  Noord-Brabant
# 94           24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 95           24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 109          24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 122          25/02/2020                  DOO    60-69    Male  Noord-Brabant
# ...                 ...                  ...      ...     ...            ...
# 1048570      16/02/2021                  DOO    40-49  Female        Utrecht
# 1048571      16/02/2021                  DOO   Oct-19  Female        Utrecht
# 1048572      16/02/2021                  DOO    20-29  Female        Utrecht
# 1048573      16/02/2021                  DOO    20-29  Female   Zuid-Holland
# 1048574      16/02/2021                  DOO    20-29  Female  Noord-Holland
#
# ...

# %%
duplicate = df[df.duplicated()]
 
print("Week_of_death :")
duplicate
# Out:
# Week_of_death :
#         Date_statistics Date_statistics_type Agegroup     Sex       Province  \
# 82           23/02/2020                  DOO    70-79    Male  Noord-Brabant
# 94           24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 95           24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 109          24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 122          25/02/2020                  DOO    60-69    Male  Noord-Brabant
# ...                 ...                  ...      ...     ...            ...
# 1048570      16/02/2021                  DOO    40-49  Female        Utrecht
# 1048571      16/02/2021                  DOO   Oct-19  Female        Utrecht
# 1048572      16/02/2021                  DOO    20-29  Female        Utrecht
# 1048573      16/02/2021                  DOO    20-29  Female   Zuid-Holland
# 1048574      16/02/2021                  DOO    20-29  Female  Noord-Holland
#
# ...

# %%
duplicate = df[df.duplicated()]
 
print("Municipal_health_service :")
duplicate
# Out:
# Municipal_health_service :
#         Date_statistics Date_statistics_type Agegroup     Sex       Province  \
# 82           23/02/2020                  DOO    70-79    Male  Noord-Brabant
# 94           24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 95           24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 109          24/02/2020                  DOO    50-59  Female  Noord-Brabant
# 122          25/02/2020                  DOO    60-69    Male  Noord-Brabant
# ...                 ...                  ...      ...     ...            ...
# 1048570      16/02/2021                  DOO    40-49  Female        Utrecht
# 1048571      16/02/2021                  DOO   Oct-19  Female        Utrecht
# 1048572      16/02/2021                  DOO    20-29  Female        Utrecht
# 1048573      16/02/2021                  DOO    20-29  Female   Zuid-Holland
# 1048574      16/02/2021                  DOO    20-29  Female  Noord-Holland
#
# ...

# %%
data = df[['Municipal_health_service']].drop_duplicates().dropna(subset=['start_station_id'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\workfuck\DEWA\PPCA.ipynb Cell 20 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/workfuck/DEWA/PPCA.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> unite = df[['Municipal_health_service']].drop_duplicates().dropna(subset=['start_station_id'])
#
# File d:\Anaconda\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File d:\Anaconda\lib\site-packages\pandas\core\frame.py:6002, in DataFrame.dropna(self, axis, how, thresh, subset, inplace)
#    6000     check = indices == -1
# ...
